# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json 


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = pd.read_csv("../output_data/cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
output_data_file.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#create empty lists
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

#weather api 
url = 'http://api.openweathermap.org/data/2.5/weather'

#print statement
print('Beginning Data Retrieval')
print('-----------------------------')

record = 0
set_count = 1
for city in cities:
    #create parameters for api call 
    params={
        "q":city,
        "units":"imperial",
        "appid": weather_api_key
    }
    try:
        response = requests.get(url, params)
        #print(response.url)
        results = response.json()
        #reformat to see data better
        #print(json.dumps(results, indent=4, sort_keys=True))
        cloudiness.append(results["clouds"]["all"])
        date.append(results["dt"])
        humidity.append(results["main"]["humidity"])
        lat.append(results["coord"]["lat"])
        lng.append(results["coord"]["lon"])
        max_temp.append(results["main"]["temp_max"])
        wind_speed.append(results["wind"]["speed"])
        #increase counter by one, include a set count 
        if record == 50:
            record = 1 
            set_count +=1
        else:
            record += 1
        country.append(results["sys"]["country"])
        city_name.append(city)
        print(f"Processing Record {record} of Set {set_count} | {city}")
        
    except Exception:
        print("City not found. Skipping...")

print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | emba
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | kurilsk
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | vostok
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 1 | sioux lookout
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | santa cruz do sul
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | tulle
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 20 of Set 1 | emerald
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | broken hill
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | farrukhnagar
# City not found. Skipping...
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | hot springs
# City not found. Skipping...
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | albanel
# Processing Record 32 of Set 1 | bonavista
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | pochutla
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | nordhausen
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | mahibadhoo
# Processing Record 42 of Set 1 | ballina
# City not found. Skipping...
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | yichang
# City not found. Skipping...
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | filadelfia
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | neuquen
# Processing Record 49 of Set 1 | nome
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | lavrentiya
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | khani
# Processing Record 6 of Set 2 | upanema
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | ahipara
# City not found. Skipping...
# Processing Record 9 of Set 2 | sampit
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | flinders
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 2 | ituacu
# Processing Record 13 of Set 2 | vokhma
# Processing Record 14 of Set 2 | airai
# City not found. Skipping...
# Processing Record 15 of Set 2 | urengoy
# Processing Record 16 of Set 2 | dvorichna
# Processing Record 17 of Set 2 | mrakovo
# Processing Record 18 of Set 2 | aykhal
# Processing Record 19 of Set 2 | srednekolymsk
# Processing Record 20 of Set 2 | nishihara
# Processing Record 21 of Set 2 | cabedelo
# Processing Record 22 of Set 2 | zhigansk
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | upernavik
# City not found. Skipping...
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | sept-iles
# Processing Record 27 of Set 2 | agadir
# Processing Record 28 of Set 2 | northam
# Processing Record 29 of Set 2 | bayan
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | vitim
# Processing Record 32 of Set 2 | north bend
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | warrnambool
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | port hedland
# Processing Record 42 of Set 2 | kozulka
# Processing Record 43 of Set 2 | sorland
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | namtsy
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | punta arenas
# Processing Record 50 of Set 2 | panaba
# Processing Record 1 of Set 3 | at-bashi
# Processing Record 2 of Set 3 | kilindoni
# Processing Record 3 of Set 3 | lukh
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | kahului
# Processing Record 6 of Set 3 | bathsheba
# Processing Record 7 of Set 3 | vanimo
# Processing Record 8 of Set 3 | kodiak
# City not found. Skipping...
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | hambantota
# Processing Record 11 of Set 3 | pahrump
# Processing Record 12 of Set 3 | marzuq
# Processing Record 13 of Set 3 | brae
# Processing Record 14 of Set 3 | rundu
# Processing Record 15 of Set 3 | paamiut
# Processing Record 16 of Set 3 | cayenne
# Processing Record 17 of Set 3 | awbari
# Processing Record 18 of Set 3 | batie
# Processing Record 19 of Set 3 | bilma
# Processing Record 20 of Set 3 | manokwari
# City not found. Skipping...
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | katsuura
# Processing Record 23 of Set 3 | barrancas
# Processing Record 24 of Set 3 | bowen
# Processing Record 25 of Set 3 | rawson
# Processing Record 26 of Set 3 | umm lajj
# Processing Record 27 of Set 3 | murgab
# Processing Record 28 of Set 3 | sao jose da coroa grande
# Processing Record 29 of Set 3 | nampula
# Processing Record 30 of Set 3 | saldanha
# Processing Record 31 of Set 3 | hobart
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | kiruna
# Processing Record 34 of Set 3 | beibei
# Processing Record 35 of Set 3 | chumikan
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | nevsehir
# Processing Record 38 of Set 3 | ozernovskiy
# Processing Record 39 of Set 3 | nanakuli
# Processing Record 40 of Set 3 | joensuu
# Processing Record 41 of Set 3 | camargo
# Processing Record 42 of Set 3 | mezhgorye
# Processing Record 43 of Set 3 | maldonado
# Processing Record 44 of Set 3 | roald
# Processing Record 45 of Set 3 | san francisco
# Processing Record 46 of Set 3 | shetpe
# Processing Record 47 of Set 3 | nouadhibou
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | tingo maria
# Processing Record 50 of Set 3 | narsaq
# Processing Record 1 of Set 4 | poso
# Processing Record 2 of Set 4 | port elizabeth
# Processing Record 3 of Set 4 | anadyr
# Processing Record 4 of Set 4 | susanville
# Processing Record 5 of Set 4 | namibe
# Processing Record 6 of Set 4 | cape town
# Processing Record 7 of Set 4 | alpena
# Processing Record 8 of Set 4 | roseburg
# Processing Record 9 of Set 4 | bamako
# Processing Record 10 of Set 4 | provideniya
# City not found. Skipping...
# Processing Record 11 of Set 4 | salalah
# Processing Record 12 of Set 4 | along
# Processing Record 13 of Set 4 | mancio lima
# City not found. Skipping...
# Processing Record 14 of Set 4 | novo oriente
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | ixtapa
# Processing Record 18 of Set 4 | nuuk
# Processing Record 19 of Set 4 | olafsvik
# Processing Record 20 of Set 4 | sistranda
# Processing Record 21 of Set 4 | port lincoln
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | japura
# Processing Record 24 of Set 4 | naze
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | ugoofaaru
# Processing Record 27 of Set 4 | westport
# Processing Record 28 of Set 4 | teyateyaneng
# Processing Record 29 of Set 4 | mabaruma
# City not found. Skipping...
# Processing Record 30 of Set 4 | leningradskiy
# Processing Record 31 of Set 4 | lata
# City not found. Skipping...
# Processing Record 32 of Set 4 | college
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | lasa
# Processing Record 35 of Set 4 | luang prabang
# Processing Record 36 of Set 4 | vila franca do campo
# Processing Record 37 of Set 4 | praia
# Processing Record 38 of Set 4 | san carlos
# Processing Record 39 of Set 4 | teknaf
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | puerto leguizamo
# Processing Record 42 of Set 4 | christchurch
# Processing Record 43 of Set 4 | tortoli
# Processing Record 44 of Set 4 | coahuayana
# City not found. Skipping...
# Processing Record 45 of Set 4 | sinnamary
# Processing Record 46 of Set 4 | eirunepe
# Processing Record 47 of Set 4 | yinchuan
# Processing Record 48 of Set 4 | anori
# Processing Record 49 of Set 4 | tupik
# Processing Record 50 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | lhokseumawe
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | evensk
# Processing Record 4 of Set 5 | kavaratti
# City not found. Skipping...
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | adolfo lopez mateos
# Processing Record 7 of Set 5 | qasigiannguit
# Processing Record 8 of Set 5 | takab
# Processing Record 9 of Set 5 | hobyo
# Processing Record 10 of Set 5 | mosjoen
# Processing Record 11 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 5 | tateyama
# Processing Record 13 of Set 5 | cabo san lucas
# Processing Record 14 of Set 5 | padang
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | sao miguel do araguaia
# Processing Record 18 of Set 5 | kumluca
# Processing Record 19 of Set 5 | puerto escondido
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | demyansk
# Processing Record 22 of Set 5 | ukiah
# Processing Record 23 of Set 5 | boke
# Processing Record 24 of Set 5 | sindor
# Processing Record 25 of Set 5 | khandbari
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | gat
# Processing Record 28 of Set 5 | itacarambi
# Processing Record 29 of Set 5 | grand gaube
# Processing Record 30 of Set 5 | tabou
# Processing Record 31 of Set 5 | vermilion
# Processing Record 32 of Set 5 | bubaque
# Processing Record 33 of Set 5 | merauke
# Processing Record 34 of Set 5 | rio grande
# Processing Record 35 of Set 5 | pangai
# Processing Record 36 of Set 5 | oum hadjer
# Processing Record 37 of Set 5 | elat
# Processing Record 38 of Set 5 | nelson bay
# Processing Record 39 of Set 5 | margate
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | diu
# Processing Record 42 of Set 5 | tambacounda
# Processing Record 43 of Set 5 | chapais
# Processing Record 44 of Set 5 | great yarmouth
# Processing Record 45 of Set 5 | urucara
# Processing Record 46 of Set 5 | nanchang
# City not found. Skipping...
# Processing Record 47 of Set 5 | kudahuvadhoo
# Processing Record 48 of Set 5 | ancud
# Processing Record 49 of Set 5 | lubango
# Processing Record 50 of Set 5 | pareora
# Processing Record 1 of Set 6 | luganville
# Processing Record 2 of Set 6 | gracac
# Processing Record 3 of Set 6 | bandiagara
# Processing Record 4 of Set 6 | comodoro rivadavia
# Processing Record 5 of Set 6 | khanpur
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | hofn
# City not found. Skipping...
# Processing Record 8 of Set 6 | cinco esquinas
# Processing Record 9 of Set 6 | yuancheng
# Processing Record 10 of Set 6 | lubao
# Processing Record 11 of Set 6 | illapel
# Processing Record 12 of Set 6 | nabire
# Processing Record 13 of Set 6 | nieuwpoort
# Processing Record 14 of Set 6 | feltre
# City not found. Skipping...
# Processing Record 15 of Set 6 | saint-pierre
# Processing Record 16 of Set 6 | sorrento
# Processing Record 17 of Set 6 | careiro da varzea
# Processing Record 18 of Set 6 | roma
# Processing Record 19 of Set 6 | tual
# Processing Record 20 of Set 6 | port hardy
# Processing Record 21 of Set 6 | bartica
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | chekmagush
# Processing Record 24 of Set 6 | sakaiminato
# Processing Record 25 of Set 6 | pitimbu
# Processing Record 26 of Set 6 | sisimiut
# City not found. Skipping...
# Processing Record 27 of Set 6 | balkanabat
# Processing Record 28 of Set 6 | la ronge
# Processing Record 29 of Set 6 | geraldton
# Processing Record 30 of Set 6 | pevek
# Processing Record 31 of Set 6 | mahebourg
# Processing Record 32 of Set 6 | exeter
# Processing Record 33 of Set 6 | adrar
# Processing Record 34 of Set 6 | arcata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 6 | zaysan
# Processing Record 36 of Set 6 | santa luzia
# Processing Record 37 of Set 6 | tasiilaq
# Processing Record 38 of Set 6 | mareeba
# Processing Record 39 of Set 6 | great falls
# Processing Record 40 of Set 6 | marihatag
# Processing Record 41 of Set 6 | orlik
# Processing Record 42 of Set 6 | khudaganj
# Processing Record 43 of Set 6 | codrington
# Processing Record 44 of Set 6 | amahai
# City not found. Skipping...
# Processing Record 45 of Set 6 | qaqortoq
# Processing Record 46 of Set 6 | humaita
# Processing Record 47 of Set 6 | sur
# Processing Record 48 of Set 6 | kamaishi
# Processing Record 49 of Set 6 | oktyabrskiy
# Processing Record 50 of Set 6 | bansang
# Processing Record 1 of Set 7 | mitsamiouli
# Processing Record 2 of Set 7 | mayumba
# Processing Record 3 of Set 7 | antalaha
# Processing Record 4 of Set 7 | shache
# Processing Record 5 of Set 7 | victor harbor
# Processing Record 6 of Set 7 | sumbe
# Processing Record 7 of Set 7 | itapage
# Processing Record 8 of Set 7 | marinette
# Processing Record 9 of Set 7 | panalingaan
# Processing Record 10 of Set 7 | seoul
# Processing Record 11 of Set 7 | saint anthony
# Processing Record 12 of Set 7 | bar-le-duc
# City not found. Skipping...
# Processing Record 13 of Set 7 | devils lake
# Processing Record 14 of Set 7 | bintulu
# Processing Record 15 of Set 7 | guayaramerin
# Processing Record 16 of Set 7 | hovd
# Processing Record 17 of Set 7 | chokurdakh
# Processing Record 18 of Set 7 | dentsville
# Processing Record 19 of Set 7 | coari
# Processing Record 20 of Set 7 | kostomuksha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 7 | dongkan
# Processing Record 22 of Set 7 | hasaki
# Processing Record 23 of Set 7 | kalamare
# Processing Record 24 of Set 7 | isla vista
# Processing Record 25 of Set 7 | buin
# Processing Record 26 of Set 7 | whitehorse
# Processing Record 27 of Set 7 | alyangula
# Processing Record 28 of Set 7 | minot
# Processing Record 29 of Set 7 | kupino
# Processing Record 30 of Set 7 | bundaberg
# Processing Record 31 of Set 7 | sabang
# Processing Record 32 of Set 7 | nuevo progreso
# Processing Record 33 of Set 7 | sobolevo
# Processing Record 34 of Set 7 | medea
# Processing Record 35 of Set 7 | znamenskoye
# Processing Record 36 of Set 7 | polyarnyy
# Processing Record 37 of Set 7 | kavieng
# Processing Record 38 of Set 7 | oytal
# City not found. Skipping...
# Processing Record 39 of Set 7 | high level
# Processing Record 40 of Set 7 | azul
# Processing Record 41 of Set 7 | igrim
# Processing Record 42 of Set 7 | kapit
# Processing Record 43 of Set 7 | paulo ramos
# Processing Record 44 of Set 7 | tuktoyaktuk
# Processing Record 45 of Set 7 | topchikha
# Processing Record 46 of Set 7 | bongaree
# Processing Record 47 of Set 7 | berlevag
# Processing Record 48 of Set 7 | zdvinsk
# Processing Record 49 of Set 7 | bagdarin
# City not found. Skipping...
# Processing Record 50 of Set 7 | saint-ambroise
# Processing Record 1 of Set 8 | sackville
# Processing Record 2 of Set 8 | shelburne
# Processing Record 3 of Set 8 | abonnema
# City not found. Skipping...
# Processing Record 4 of Set 8 | batagay-alyta
# Processing Record 5 of Set 8 | moyale
# Processing Record 6 of Set 8 | xichang
# Processing Record 7 of Set 8 | ilo
# Processing Record 8 of Set 8 | ilesha
# Processing Record 9 of Set 8 | zhezkazgan
# Processing Record 10 of Set 8 | lieksa
# Processing Record 11 of Set 8 | vestmanna
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | klaipeda
# Processing Record 14 of Set 8 | banda aceh
# Processing Record 15 of Set 8 | guadalupe
# City not found. Skipping...
# Processing Record 16 of Set 8 | daoukro
# Processing Record 17 of Set 8 | guerrero negro
# Processing Record 18 of Set 8 | fairbanks
# Processing Record 19 of Set 8 | clyde river
# Processing Record 20 of Set 8 | ulaanbaatar
# Processing Record 21 of Set 8 | husavik
# Processing Record 22 of Set 8 | yelan-koleno
# Processing Record 23 of Set 8 | lazaro cardenas
# Processing Record 24 of Set 8 | san patricio
# Processing Record 25 of Set 8 | aubenas
# Processing Record 26 of Set 8 | canico
# Processing Record 27 of Set 8 | sao filipe
# Processing Record 28 of Set 8 | mao
# Processing Record 29 of Set 8 | novoagansk
# Processing Record 30 of Set 8 | goderich
# Processing Record 31 of Set 8 | choix
# City not found. Skipping...
# Processing Record 32 of Set 8 | yavas
# Processing Record 33 of Set 8 | saint-georges
# Processing Record 34 of Set 8 | bulgan
# Processing Record 35 of Set 8 | mudigere
# Processing Record 36 of Set 8 | tanhacu
# Processing Record 37 of Set 8 | zelenoborskiy
# Processing Record 38 of Set 8 | biggar
# Processing Record 39 of Set 8 | miri
# Processing Record 40 of Set 8 | hermon
# Processing Record 41 of Set 8 | rurrenabaque
# Processing Record 42 of Set 8 | haines junction
# Processing Record 43 of Set 8 | semirom
# Processing Record 44 of Set 8 | sola
# Processing Record 45 of Set 8 | council bluffs
# Processing Record 46 of Set 8 | chake chake
# Processing Record 47 of Set 8 | nichinan
# Processing Record 48 of Set 8 | portland
# Processing Record 49 of Set 8 | san quintin
# Processing Record 50 of Set 8 | richards bay
# City not found. Skipping...
# Processing Record 1 of Set 9 | teseney
# Processing Record 2 of Set 9 | makinsk
# Processing Record 3 of Set 9 | tiksi
# Processing Record 4 of Set 9 | port-gentil
# Processing Record 5 of Set 9 | barra dos coqueiros
# Processing Record 6 of Set 9 | yulara
# Processing Record 7 of Set 9 | uni
# Processing Record 8 of Set 9 | igarka
# Processing Record 9 of Set 9 | kloulklubed
# Processing Record 10 of Set 9 | isangel
# Processing Record 11 of Set 9 | valer
# Processing Record 12 of Set 9 | tilichiki
# Processing Record 13 of Set 9 | huarmey
# Processing Record 14 of Set 9 | kibre mengist
# Processing Record 15 of Set 9 | sabha
# City not found. Skipping...
# Processing Record 16 of Set 9 | hami
# Processing Record 17 of Set 9 | shubarshi
# Processing Record 18 of Set 9 | cantaura
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | sambava
# Processing Record 21 of Set 9 | anzio
# Processing Record 22 of Set 9 | cockburn town
# Processing Record 23 of Set 9 | axim
# Processing Record 24 of Set 9 | los llanos de aridane
# Processing Record 25 of Set 9 | cap malheureux
# Processing Record 26 of Set 9 | kapoeta
# Processing Record 27 of Set 9 | minsk
# Processing Record 28 of Set 9 | ayan
# Processing Record 29 of Set 9 | muros
# Processing Record 30 of Set 9 | schleswig
# Processing Record 31 of Set 9 | smolensk
# Processing Record 32 of Set 9 | oistins
# Processing Record 33 of Set 9 | labuhan
# Processing Record 34 of Set 9 | peruibe
# City not found. Skipping...
# Processing Record 35 of Set 9 | mandan
# Processing Record 36 of Set 9 | batagay
# Processing Record 37 of Set 9 | brive-la-gaillarde
# Processing Record 38 of Set 9 | kismayo
# Processing Record 39 of Set 9 | rorvik
# Processing Record 40 of Set 9 | catabola
# Processing Record 41 of Set 9 | port macquarie
# Processing Record 42 of Set 9 | hanyang
# City not found. Skipping...
# Processing Record 43 of Set 9 | cururupu
# Processing Record 44 of Set 9 | tocopilla
# Processing Record 45 of Set 9 | ucluelet
# Processing Record 46 of Set 9 | san fernando
# Processing Record 47 of Set 9 | erdaojiang
# Processing Record 48 of Set 9 | kamenka
# Processing Record 49 of Set 9 | hailin
# Processing Record 50 of Set 9 | lompoc
# Processing Record 1 of Set 10 | vao
# Processing Record 2 of Set 10 | krasnovishersk
# Processing Record 3 of Set 10 | san andres
# Processing Record 4 of Set 10 | conceicao das alagoas
# Processing Record 5 of Set 10 | esik
# Processing Record 6 of Set 10 | samarai
# City not found. Skipping...
# Processing Record 7 of Set 10 | haikou
# Processing Record 8 of Set 10 | apiai
# Processing Record 9 of Set 10 | sfantu gheorghe
# Processing Record 10 of Set 10 | basar
# Processing Record 11 of Set 10 | marsa matruh
# City not found. Skipping...
# Processing Record 12 of Set 10 | hamilton
# City not found. Skipping...
# Processing Record 13 of Set 10 | ngunguru
# Processing Record 14 of Set 10 | kathu
# Processing Record 15 of Set 10 | yar-sale
# Processing Record 16 of Set 10 | moose factory
# Processing Record 17 of Set 10 | la libertad
# Processing Record 18 of Set 10 | vila
# Processing Record 19 of Set 10 | faanui
# Processing Record 20 of Set 10 | santa ines
# Processing Record 21 of Set 10 | gao
# Processing Record 22 of Set 10 | nagorsk
# Processing Record 23 of Set 10 | ryotsu
# Processing Record 24 of Set 10 | ilulissat
# Processing Record 25 of Set 10 | marawi
# Processing Record 26 of Set 10 | pokhara
# Processing Record 27 of Set 10 | bozoum
# Processing Record 28 of Set 10 | strezhevoy
# Processing Record 29 of Set 10 | hualmay
# Processing Record 30 of Set 10 | medvedevo
# Processing Record 31 of Set 10 | pandan niog
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | nhulunbuy
# Processing Record 34 of Set 10 | ochamchira
# City not found. Skipping...
# Processing Record 35 of Set 10 | chase
# Processing Record 36 of Set 10 | gidole
# Processing Record 37 of Set 10 | mnogovershinnyy
# Processing Record 38 of Set 10 | kirakira
# City not found. Skipping...
# Processing Record 39 of Set 10 | nadym
# Processing Record 40 of Set 10 | fort madison
# City not found. Skipping...
# Processing Record 41 of Set 10 | iranshahr
# Processing Record 42 of Set 10 | yarmouth
# Processing Record 43 of Set 10 | rio gallegos
# Processing Record 44 of Set 10 | phenix city
# Processing Record 45 of Set 10 | asau
# Processing Record 46 of Set 10 | shaunavon
# Processing Record 47 of Set 10 | kanye
# Processing Record 48 of Set 10 | hokitika
# Processing Record 49 of Set 10 | brokopondo
# Processing Record 50 of Set 10 | acapulco
# City not found. Skipping...
# Processing Record 1 of Set 11 | portales
# Processing Record 2 of Set 11 | muisne
# Processing Record 3 of Set 11 | arrifes
# Processing Record 4 of Set 11 | jasper
# Processing Record 5 of Set 11 | dhidhdhoo
# Processing Record 6 of Set 11 | elizabeth city
# Processing Record 7 of Set 11 | pimampiro
# Processing Record 8 of Set 11 | troitskoye
# Processing Record 9 of Set 11 | cacu
# Processing Record 10 of Set 11 | oron
# Processing Record 11 of Set 11 | port moresby
# Processing Record 12 of Set 11 | burnie
# Processing Record 13 of Set 11 | tura
# Processing Record 14 of Set 11 | holland
# Processing Record 15 of Set 11 | saint-augustin
# Processing Record 16 of Set 11 | kimbe
# Processing Record 17 of Set 11 | puerto del rosario
# Processing Record 18 of Set 11 | hajnowka
# Processing Record 19 of Set 11 | diapaga
# Processing Record 20 of Set 11 | severnyy
# Processing Record 21 of Set 11 | norrtalje
# Processing Record 22 of Set 11 | puri
# Processing Record 23 of Set 11 | montalto uffugo
# Processing Record 24 of Set 11 | borogontsy
# Processing Record 25 of Set 11 | nizwa
# Processing Record 26 of Set 11 | mbaiki
# Processing Record 27 of Set 11 | kununurra
# Processing Record 28 of Set 11 | kayerkan
# Processing Record 29 of Set 11 | beringovskiy
# Processing Record 30 of Set 11 | taos
# Processing Record 31 of Set 11 | kalmunai
# Processing Record 32 of Set 11 | kuybysheve
# Processing Record 33 of Set 11 | kenai
# Processing Record 34 of Set 11 | oksfjord
# Processing Record 35 of Set 11 | andenes
# Processing Record 36 of Set 11 | kozhva
# Processing Record 37 of Set 11 | ayolas
# Processing Record 38 of Set 11 | bad waldsee
# Processing Record 39 of Set 11 | sao felix do xingu
# Processing Record 40 of Set 11 | barcelona
# Processing Record 41 of Set 11 | digha
# Processing Record 42 of Set 11 | juba
# Processing Record 43 of Set 11 | umm kaddadah
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | isabela
# Processing Record 46 of Set 11 | neiafu
# Processing Record 47 of Set 11 | villazon
# Processing Record 48 of Set 11 | maryborough
# City not found. Skipping...
# Processing Record 49 of Set 11 | abhar
# Processing Record 50 of Set 11 | holguin
# Processing Record 1 of Set 12 | songjianghe
# City not found. Skipping...
# Processing Record 2 of Set 12 | darhan
# Processing Record 3 of Set 12 | dalnerechensk
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dictionary with above lists
weather_data = pd.DataFrame({
    "City":city_name,
    "Cloudiness": cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Long":lng,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
})
#create df from weather_data
weather_df = pd.DataFrame(weather_data)
#display count of weather data
weather_df.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Long          553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
#save df as CSV
weather_df.to_csv("../output_data/weather_df.csv")

#display data
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat    Long  \
# 0       emba          99      KZ  1584643002        71  48.83   58.14
# 1    mataura          50      NZ  1584643003        68 -46.19  168.86
# 2       chuy           3      UY  1584643003        50 -33.70  -53.46
# 3  esperance          75      AU  1584643003        93 -33.87  121.90
# 4    kurilsk          79      RU  1584643004        99  45.23  147.88
#
#    Max Temp  Wind Speed
# 0     36.41        7.65
# 1     50.00       14.00
# 2     77.09       16.84
# 3     59.00        4.70
# 4     36.05        7.31

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", color="red", s=10)
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %%
#Temperatures become warmer as latitude approaches 0 degrees

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", color="orange", s=10)
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# Text(0, 0.5, 'Humidity')

# %%
#humidity is quite variable but shows higher humidity in latitudes 40-70

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", color="blue", s=10)
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# Text(0, 0.5, 'Cloudiness')

# %%
#cludiness to latitude is variable across temps and latitudes

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o", color="tan", s=10)
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Windspeed")
# Out:
# Text(0, 0.5, 'Windspeed')

# %%
#windspeeds between 0-20 are present actross latitudes

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
